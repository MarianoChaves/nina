# %%
import pandas as pd

# %%
df = pd.read_csv('xsec_cc.dat', delimiter=" ", header=None)
df["logenergy"]=10**df[0]
df
# Out:
#           0         1         2  3         4         5  6   7  logenergy
# 0  -0.97954  0.000000  0.000000  0  0.000000  0.000000  0 NaN   0.104824
# 1  -0.93954  0.000000  0.000000  0  0.000000  0.000000  0 NaN   0.114937
# 2  -0.89954  0.246185  0.000000  0  0.000000  0.000000  0 NaN   0.126026
# 3  -0.85954  0.000000  0.000000  0  0.087575  0.000000  0 NaN   0.138185
# 4  -0.81954  0.168208  0.000000  0  0.000000  0.000000  0 NaN   0.151517
# ..      ...       ...       ... ..       ...       ... ..  ..        ...
# 70  1.73012  0.669096  0.684607  0  0.308424  0.303445  0 NaN  53.718020
# 71  1.79032  0.661357  0.674595  0  0.307325  0.303802  0 NaN  61.704949
# 72  1.85053  0.694078  0.673215  0  0.302910  0.311621  0 NaN  70.881027
# 73  1.91073  0.671643  0.663316  0  0.310888  0.308908  0 NaN  81.419794
# 74  1.97094  0.671950  0.677586  0  0.311679  0.309399  0 NaN  93.527645
#
# [75 rows x 9 columns]

# %%
f = open('xsec_cc.dat')

# %%
f.readlines()
# Out:
# ['-0.97954 0 0 0 0 0 0 \n',
#  '-0.93954 0 0 0 0 0 0 \n',
#  '-0.89954 0.246185 0 0 0 0 0 \n',
#  '-0.85954 0 0 0 0.0875746 0 0 \n',
#  '-0.81954 0.168208 0 0 0 0 0 \n',
#  '-0.77954 0 0 0 0 0 0 \n',
#  '-0.73954 0.30005 0 0 0.053271 0 0 \n',
#  '-0.69954 0 0.19523 0 0.0837283 0 0 \n',
#  '-0.65954 0.208038 0.421675 0 0.0765574 0.0705436 0 \n',
#  '-0.61954 0.294452 0.286933 0 0.12324 0.0617671 0 \n',
#  '-0.57954 0.996875 0.626276 0 0.143986 0.0508795 0 \n',
#  '-0.53954 0.548275 0.20509 0 0.0990712 0.147863 0 \n',
#  '-0.49954 0.55011 0.55634 0 0.076725 0.151458 0 \n',
#  '-0.45954 0.446397 0.366665 0 0.129482 0.0845417 0 \n',
#  '-0.41954 0.632635 0.528393 0 0.152144 0.171336 0 \n',
#  '-0.37954 0.495385 0.72357 0 0.174457 0.0831018 0 \n',
#  '-0.33954 0.744508 0.68563 0 0.205045 0.118651 0 \n',
#  '-0.29954 0.734444 0.716721 0 0.154405 0.115049 0 \n',
#  '-0.25954 0.975346 0.820037 0 0.221854 0.162892 0 \n',
#  '-0.21954 0.827747 0.730607 0 0.137574 0.216276 0 \n',
# ...
